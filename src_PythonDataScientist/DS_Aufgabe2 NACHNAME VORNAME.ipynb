# %% [markdown]
# # **Aufgabe 2 - Musterlösung**
#
# Alle nötigen Informationen rund um das Lösen und Einreichen der Aufgabe befindet sich im Kapitel **Aufgabe II** des Online-Materials.
#
# ## **Teil 1: Multiple-Choice-Fragen**
#
# Beantworte die folgenden Multiple-Choice-Fragen.
#
# - Bei jeder Frage können eine ODER mehrere Antworten korrekt sein
# - Es ist immer mindestens eine Antwort korrekt
#
# Trage deine Antworten in die Code-Zelle nach den Fragen ein, indem du die entsprechenden Buchstaben in die vorgegebenen Variablen einträgst. Wenn mehrere Antworten richtig sind, trage alle richtigen Buchstaben ein (z.B. `antwort_1 = 'a,c,d'`).
#
# ----
# **Frage 1: Was zeigt ein Q-Q-Plot bei der Modelldiagnostik?**
#
# - a) Die Beziehung zwischen Residuen und vorhergesagten Werten
# - b) Ob die Residuen normalverteilt sind
# - c) Die Korrelation zwischen unabhängigen Variablen
# - d) Die Homoskedastizität der Residuen

# %%
antwort_1 = ''

# %% [markdown]
# ----
# **Frage 2: Was ist der Hauptunterschied zwischen ANCOVA und Moderationsanalyse?**
#
# - a) ANCOVA verwendet kategorische Variablen, Moderationsanalyse nur metrische
# - b) ANCOVA nimmt keine Interaktion zwischen Faktor und Kovariable an, Moderationsanalyse schon
# - c) ANCOVA ist für Regression, Moderationsanalyse für ANOVA gedacht
# - d) ANCOVA führt zu parallelen Regressionsgeraden, Moderationsanalyse zu unterschiedlichen Steigungen
# - e) Es gibt keinen wesentlichen Unterschied zwischen beiden Methoden

# %%
antwort_2 = ''

# %% [markdown]
# ----
# **Frage 3: Was bedeutet es, wenn die Odds in der logistischen Regression 2.5 betragen?**
#
# - a) Die Wahrscheinlichkeit für das Ereignis ist 2.5
# - b) Das Ereignis ist 2.5-mal wahrscheinlicher als das Nicht-Ereignis
# - c) Die Wahrscheinlichkeit für das Ereignis beträgt 71.4%
# - d) Der Logit-Wert ist ln(2.5)
# - e) Die Wahrscheinlichkeit für das Ereignis beträgt 25%

# %%
antwort_3 = ''

# %% [markdown]
# ----
# **Frage 4: Welche Aussagen zu Precision und Recall sind korrekt?**
#
# - a) Precision fragt: "Von allen positiven Vorhersagen, wie viele waren korrekt?"
# - b) Recall fragt: "Von allen tatsächlich positiven Fällen, wie viele wurden gefunden?"
# - c) Hohe Precision bedeutet automatisch hohen Recall
# - d) Bei unausgewogenen Datensätzen ist Accuracy oft weniger aussagekräftig als Precision/Recall
# - e) F1-Score ist das harmonische Mittel von Precision und Recall

# %%
antwort_4 = ''

# %% [markdown]
# ----
# **Frage 5: Was sind die Hauptvorteile von Decision Trees?**
#
# - a) Sie sind immer genauer als andere Klassifikationsverfahren
# - b) Sie sind sehr gut interpretierbar durch Wenn-Dann-Regeln
# - c) Sie sind robust gegenüber Overfitting
# - d) Sie können automatisch Feature-Auswahl durchführen

# %%
antwort_5 = ''

# %% [markdown]
# ----
# **Frage 6: Welche Aussagen zur Stratified K-Fold Cross Validation sind richtig?**
#
# - a) Sie sorgt dafür, dass jeder Fold die gleiche Klassenverteilung hat wie der Gesamtdatensatz
# - b) Sie ist besonders wichtig bei unausgewogenen Datensätzen
# - c) Sie kann nur bei Klassifikationsproblemen verwendet werden
# - d) Sie verhindert, dass manche Folds sehr unbalancierte Test-Sets haben

# %%
antwort_6 = ''

# %% [markdown]
# ----
# **Frage 7: Was zeigt eine signifikante Interaktion in der 2-way ANOVA?**
#
# - a) Die Haupteffekte sind nicht interpretierbar
# - b) Der Effekt eines Faktors hängt vom Level des anderen Faktors ab
# - c) Die Daten sind nicht normalverteilt
# - d) Es gibt einen Fehler in der Datenerfassung
# - e) Die Interaktionslinien im Interaktionsplot sind parallel

# %%
antwort_7 = ''

# %% [markdown]
# ----
# ## **Teil 2: Machine Learning mit dem Bodyfat-Datensatz**
#
# In dieser Aufgabe wirst du logistische Regression und Decision Trees auf den Bodyfat-Datensatz anwenden. Im Gegensatz zu Aufgabe I vor einigen Wochen fokussieren wir uns diesmal auf Klassifikation statt Regression.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import RepeatedStratifiedKFold, cross_validate
from sklearn.metrics import classification_report, roc_curve, auc, accuracy_score

# Datensatz laden
url = "https://raw.githubusercontent.com/SchmidtPaul/ExampleData/refs/heads/main/bodyfat/bodyfat.csv"
df = pd.read_csv(url)

# %% [markdown]
# Dieser Datensatz enthält Körperfettmessungen und anthropometrische Daten von 252 Männern, wobei die Körperfettanteile durch Unterwasserwiegen sowie verschiedene Körperumfangsmessungen bestimmt wurden. Jede Zeile repräsentiert einen männlichen Probanden mit folgenden Variablen:
#
# - Density: Durch Unterwasserwiegen bestimmte Körperdichte (g/cm³)
# - BodyFat: Nach Siri's Gleichung (1956) berechneter Körperfettanteil (%)
# - Age: Alter in Jahren
# - Weight: Gewicht in Pfund (lbs)
# - Height: Körpergröße in Zoll (inches)
# - Neck: Halsumfang in Zentimetern (cm)
# - Chest: Brustumfang in Zentimetern (cm)
# - Abdomen: Bauchumfang in Zentimetern (cm), gemessen auf Höhe der Beckenkämme/Nabel
# - Hip: Hüftumfang in Zentimetern (cm)
# - Thigh: Oberschenkelumfang in Zentimetern (cm)
# - Knee: Knieumfang in Zentimetern (cm)
# - Ankle: Knöchelumfang in Zentimetern (cm)
# - Biceps: Bizepsumfang (gestreckt) in Zentimetern (cm)
# - Forearm: Unterarmumfang in Zentimetern (cm)
# - Wrist: Handgelenkumfang in Zentimetern (cm)
#
# ----
# **Aufgabe 2.1: Datenvorverarbeitung**
#
# 1. Selektiere nur die folgenden Variablen: `['Age', 'Weight', 'Height', 'Abdomen', 'Hip', 'BodyFat']`
# 2. Erstelle eine neue binäre Variable `'Overweight'` mit der Regel: `Overweight = 1` wenn BodyFat größer 25 ist, sonst `0`
# 3. Gib die Anzahl der Beobachtungen pro Kategorie aus (wie viele Personen sind übergewichtig vs. nicht-übergewichtig)

# %% [markdown]
# ----
#
# **Aufgabe 2.2: Einzelne logistische Regressionen (in-sample)**
#
# Für jedes der fünf Features (`Age`, `Weight`, `Height`, `Abdomen`, `Hip`) soll eine separate logistische Regression angepasst werden:
#
# - a) Erstelle für jedes Feature ein eigenes logistisches Regressionsmodell mit `Overweight` als Zielvariable
# - b) Erstelle einen DataFrame mit den in-sample Metriken aller Einzelmodelle:
#    - Spalten: `Feature`, `Accuracy`, `Precision`, `Recall`, `F1-Score`, `ROC-AUC`
#    - Sortiert nach In-sample Accuracy (absteigend)
# - c) Visualisiere alle fünf Modelle in einer einzigen Figure (z.B. als 2×3 Subplot-Anordnung):
#    - Datenpunkte als Scatter mit Feature auf x-Achse und `Overweight` auf y-Achse
#    - Sigmoid-Kurve in rot
#    - In-sample Accuracy-Wert als Label im Zentrum jedes Plots
# - d) Identifiziere das beste Einzelmodell laut In-sample Accuracy-Wert

# %% [markdown]
# ----
#
# **Aufgabe 2.3: Multiple logistische Regression (in-sample)**
#
# - a) Erstelle eine weitere logistische Regression, diesmal mit **allen fünf Features** als Prädiktoren
# - b) Berechne die in-sample Accuracy und vergleiche sie mit dem besten Einzelmodell aus 2.2
# - c) Erstelle einen ROC-Kurven-Vergleich mit AUC-Werte in der Legende zwischen:
#    - Beste einfache logistische Regression (aus 2.2)
#    - Multiple logistische Regression (aus dieser Teilaufgabe)

# %% [markdown]
# ----
#
# **Aufgabe 2.4: Decision Trees (in-sample)**
#
# - a) Erstelle **zwei separate** Decision Tree Klassifikatoren:
#    - Modell 1: `max_depth=2`
#    - Modell 2: `max_depth=4`
#    - Beide mit allen fünf Features als Input
# - b) Berechne die in-sample Accuracy für beide Modelle
# - c) Visualisiere beide Bäume mit:
#    - Feature-Namen als Labels
#    - Klassen-Namen: `['Nicht-übergewichtig', 'Übergewichtig']`
#    - Accuracy im Titel jedes Baums
#    - (Es muss aufgrund der vielen Nodes nicht annähernd jeder Wert erkennbar sein)

# %% [markdown]
# ----
# **Aufgabe 2.5: Kreuzvalidierung-Vergleich (out-of-sample)**
#
# Vergleiche nun alle vier Modelle mitels Kreuzvalidierung:
#
# - a) Verwende wiederholte, stratifizierte k-fold Kreuzvalidierung mit 5 splits, 8 Wiederholungen und `random_state=42`
# - b) Berechne damit jeweils die out-of-sample Accuracy für:
#    - Bestes Einzelmodell (aus 2.2)
#    - Multiple logistische Regression (aus 2.3)
#    - Decision Tree mit `max_depth=2` (aus 2.4)
#    - Decision Tree mit `max_depth=4` (aus 2.4)
# - c) Erstelle einen DataFrame mit den Ergebnissen:
#    - Spalten: `Modell`, `In-Sample Accuracy`, `Out-of-Sample Accuracy`
#    - Zeilen: eine für jedes der 4 Modelle
# - d) Visualisiere die Ergebnisse:
#    - X-Achse: Die vier Modelle
#    - Y-Achse: Accuracy
#    - Rote Linie und Punkte: In-Sample Accuracy
#    - Blaue Linie und Punkte: Out-of-Sample Accuracy
#    - Pfeil mit Label "Modell der Wahl" zeigt auf das Modell mit der besten out-of-sample accuracy
